# %%
import pandas as pd

# %%
df = pd.read_csv('cars.csv')
df.head()
# Out:
# C:\Users\Adrian\AppData\Local\Temp\ipykernel_20836\1410510255.py:1: DtypeWarning: Columns (9,11,12,13,14,15,16,17,19,20,24,27,29,33,43,44,47,49,51,69,75,77) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('cars.csv')
#    id Make Modle    Generation  Year_from  Year_to     Series    Trim  \
# 0   1   AC   ACE  1 generation     1993.0   2000.0  Cabriolet  3.5 MT
# 1   2   AC   ACE  1 generation     1993.0   2000.0  Cabriolet  4.6 MT
# 2   3   AC   ACE  1 generation     1993.0   2000.0  Cabriolet  4.9 AT
# 3   4   AC   ACE  1 generation     1993.0   2000.0   Roadster  2.9 AT
# 4   5   AC   ACE  1 generation     1993.0   2000.0   Roadster  2.9 MT
#
#    Body_type load_height_mm  ... front_suspension steering_type car_class  \
# 0  Cabriolet            NaN  ...  Helical springs           NaN       NaN
# 1  Cabriolet            NaN  ...  Helical springs           NaN       NaN
# ...

# %%
df = df[
    [
        'id',
        'Make',
        'Modle',
        'Generation',
        'Year_from',
        'Year_to',
        'Series',
        'Trim',
        'Body_type',
        # 'number_of_seats',
        # 'length_mm',
        # 'width_mm',
        # 'height_mm',
        # 'wheelbase_mm',
        # 'turning_circle_m',
        'full_weight_kg',
        'max_trunk_capacity_l',
        'drive_wheels',
        'transmission',
        'cylinder_layout',
        'number_of_cylinders',
        'engine_type',
        # 'valves_per_cylinder',
        'cylinder_bore_mm',
        'stroke_cycle_mm',
        'capacity_cm3',
        'maximum_torque_n_m',
        'turnover_of_maximum_torque_rpm',
        'engine_hp',
        'engine_hp_rpm',
        'acceleration_0_100_km/h_s',
        'max_speed_km_per_h',
        'number_of_gears',
        'fuel_tank_capacity_l',
        'mixed_fuel_consumption_per_100_km_l',
        'city_fuel_per_100km_l',
        'highway_fuel_per_100km_l'
        # 'emiussion_standard'
        ]]
df
# Out:
#           id Make     Modle    Generation  Year_from  Year_to       Series  \
# 0          1   AC       ACE  1 generation     1993.0   2000.0    Cabriolet
# 1          2   AC       ACE  1 generation     1993.0   2000.0    Cabriolet
# 2          3   AC       ACE  1 generation     1993.0   2000.0    Cabriolet
# 3          4   AC       ACE  1 generation     1993.0   2000.0     Roadster
# 4          5   AC       ACE  1 generation     1993.0   2000.0     Roadster
# ...      ...  ...       ...           ...        ...      ...          ...
# 70818  70983   ZX  Landmark  1 generation     2007.0   2009.0  SUV 5 doors
# 70819  70984   ZX  Landmark  1 generation     2007.0   2009.0  SUV 5 doors
# 70820  70985   ZX  Landmark  1 generation     2007.0   2009.0  SUV 5 doors
# 70821  70986   ZX  Landmark  1 generation     2007.0   2009.0  SUV 5 doors
# 70822  70987   ZX  Landmark  1 generation     2007.0   2009.0  SUV 5 doors
#
#              Trim  Body_type  full_weight_kg  ...  \
# ...

# %%
df = df.rename(columns={
    'Modle': 'Model',
    'engine_type':'fuel_type',})
df = df.dropna()
df
# Out:
#           id      Make    Model               Generation  Year_from  Year_to  \
# 49        50     Acura  Integra             1 generation     1991.0   2002.0
# 50        51     Acura  Integra             1 generation     1991.0   2002.0
# 51        52     Acura  Integra             1 generation     1991.0   2002.0
# 54        55     Acura      MDX             1 generation     2001.0   2006.0
# 60        61     Acura      MDX             3 generation     2013.0   2020.0
# ...      ...       ...      ...                      ...        ...      ...
# 70657  70822    Vortex   Estina             1 generation     2008.0   2013.0
# 70663  70828    Vortex    Tingo  1 generation [redesign]     2012.0   2013.0
# 70668  70833  Wartburg      353             1 generation     1966.0   1988.0
# 70733  70898       ZAZ     1103             1 generation     2000.0   2011.0
# 70739  70904       ZAZ     1105             1 generation     1994.0   1997.0
#
# ...

# %%
allowed_fuel_types = ['Diesel', 'Gasoline', 'Hybrid', 'Gas']

df = df[df['fuel_type'].isin(allowed_fuel_types)]

df
# Out:
#           id      Make    Model               Generation  Year_from  Year_to  \
# 49        50     Acura  Integra             1 generation     1991.0   2002.0
# 50        51     Acura  Integra             1 generation     1991.0   2002.0
# 51        52     Acura  Integra             1 generation     1991.0   2002.0
# 54        55     Acura      MDX             1 generation     2001.0   2006.0
# 60        61     Acura      MDX             3 generation     2013.0   2020.0
# ...      ...       ...      ...                      ...        ...      ...
# 70657  70822    Vortex   Estina             1 generation     2008.0   2013.0
# 70663  70828    Vortex    Tingo  1 generation [redesign]     2012.0   2013.0
# 70668  70833  Wartburg      353             1 generation     1966.0   1988.0
# 70733  70898       ZAZ     1103             1 generation     2000.0   2011.0
# 70739  70904       ZAZ     1105             1 generation     1994.0   1997.0
#
# ...

# %%
allowed_transmisions = ['Automatic', 'Manual']

df = df[df['transmission'].isin(allowed_transmisions)]

df
# Out:
#           id      Make    Model               Generation  Year_from  Year_to  \
# 49        50     Acura  Integra             1 generation     1991.0   2002.0
# 50        51     Acura  Integra             1 generation     1991.0   2002.0
# 51        52     Acura  Integra             1 generation     1991.0   2002.0
# 54        55     Acura      MDX             1 generation     2001.0   2006.0
# 60        61     Acura      MDX             3 generation     2013.0   2020.0
# ...      ...       ...      ...                      ...        ...      ...
# 70657  70822    Vortex   Estina             1 generation     2008.0   2013.0
# 70663  70828    Vortex    Tingo  1 generation [redesign]     2012.0   2013.0
# 70668  70833  Wartburg      353             1 generation     1966.0   1988.0
# 70733  70898       ZAZ     1103             1 generation     2000.0   2011.0
# 70739  70904       ZAZ     1105             1 generation     1994.0   1997.0
#
# ...

# %%
drive_wheels_mapping = {
    'Rear wheel drive': 'rwd',
    'Front wheel drive': 'fwd',
    'All wheel drive (AWD)': 'awd',
    'Four wheel drive (4WD)': '4wd'
}

df['drive_wheels'] = df['drive_wheels'].replace(drive_wheels_mapping)
# Out:
# C:\Users\Adrian\AppData\Local\Temp\ipykernel_20836\772990976.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['drive_wheels'] = df['drive_wheels'].replace(drive_wheels_mapping)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None) 

df.head()
# Out:
#     id   Make    Model    Generation  Year_from  Year_to     Series  \
# 49  50  Acura  Integra  1 generation     1991.0   2002.0      Sedan
# 50  51  Acura  Integra  1 generation     1991.0   2002.0      Sedan
# 51  52  Acura  Integra  1 generation     1991.0   2002.0      Sedan
# 54  55  Acura      MDX  1 generation     2001.0   2006.0  Crossover
# 60  61  Acura      MDX  3 generation     2013.0   2020.0  Crossover
#
#           Trim  Body_type  full_weight_kg max_trunk_capacity_l drive_wheels  \
# 49      1.8 AT      Sedan          1600.0                370.0          fwd
# 50      1.8 MT      Sedan          1600.0                370.0          fwd
# 51      1.8 MT      Sedan          1650.0                311.0          fwd
# 54  3.5 AT 4WD  Crossover          2580.0               2308.0          awd
# 60  3.5 AT 4WD  Crossover          2575.0               1344.0          awd
#
#    transmission cylinder_layout  number_of_cylinders fuel_type  \
# ...

# %%
print(df['Body_type'].unique())
print(df['drive_wheels'].unique())
print(df['transmission'].unique())
print(df['cylinder_layout'].unique())
print(df['number_of_cylinders'].unique())
print(df['fuel_type'].unique())
print(df['number_of_gears'].unique())
# Out:
# ['Sedan' 'Crossover' 'Coupe' 'Hatchback' 'Liftback' 'Wagon' 'Cabriolet'
#  'Roadster' 'Minivan' 'Pickup' 'Fastback' 'Targa']
# ['fwd' 'awd' 'rwd' '4wd']
# ['Automatic' 'Manual']
# ['Inline' 'V-type' 'Opposed' 'W-type' 'Rotary-piston']
# [ 4.  6.  5.  8. 12.  3. 10.  2.]
# ['Gasoline' 'Diesel' 'Hybrid' 'Gas']
# [4. 5. 6. 8. 3. 7. 2. 9.]

# %%
# Alternatywne podejście dla wielu kolumn
numeric_columns = ['full_weight_kg', 'max_trunk_capacity_l', 'capacity_cm3', 'maximum_torque_n_m', 'engine_hp', 'engine_hp_rpm', 'max_speed_km_per_h', 'fuel_tank_capacity_l']

for col in numeric_columns:
    df[col] = (df[col]
              .astype(str)
              .str.replace(',', '.')
              .astype(float)
              .round()
              .astype(int))
# Out:
# C:\Users\Adrian\AppData\Local\Temp\ipykernel_20836\3186194076.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = (df[col]
# C:\Users\Adrian\AppData\Local\Temp\ipykernel_20836\3186194076.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = (df[col]
# C:\Users\Adrian\AppData\Local\Temp\ipykernel_20836\3186194076.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df = df.astype({
    'id': 'int',
    'Make': 'string',
    'Model': 'string',
    'Generation': 'string',
    'Year_from': 'int',
    'Year_to': 'int',
    'Series': 'string',
    'Trim': 'string',
    'Body_type': 'string',
    'full_weight_kg': 'int',
    'max_trunk_capacity_l': 'int',
    'drive_wheels': 'string',
    'transmission': 'string',
    'cylinder_layout': 'string',
    'number_of_cylinders': 'int',
    'fuel_type': 'string',
    'cylinder_bore_mm': 'float',
    'stroke_cycle_mm': 'float',
    'capacity_cm3': 'int',
    'maximum_torque_n_m': 'int',
    'turnover_of_maximum_torque_rpm': 'int',
    'engine_hp': 'int',
    'engine_hp_rpm': 'int',
    'acceleration_0_100_km/h_s': 'float',
    'max_speed_km_per_h': 'int',
    'number_of_gears': 'int',
    'fuel_tank_capacity_l': 'int',
    'mixed_fuel_consumption_per_100_km_l': 'float',
    'city_fuel_per_100km_l': 'float',
    'highway_fuel_per_100km_l': 'float'
})

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17077 entries, 49 to 70739
# Data columns (total 30 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   17077 non-null  int32
#  1   Make                                 17077 non-null  string
#  2   Model                                17077 non-null  string
#  3   Generation                           17077 non-null  string
#  4   Year_from                            17077 non-null  int32
#  5   Year_to                              17077 non-null  int32
#  6   Series                               17077 non-null  string
#  7   Trim                                 17077 non-null  string
#  8   Body_type                            17077 non-null  string
#  9   full_weight_kg                       17077 non-null  int32
#  10  max_trunk_capacity_l                 17077 non-null  int32
# ...

# %%
df = df[df['Year_to'] != 0]

# %%
df.to_csv('processed_cars.csv', index=False)

# %%
selected_cars = df[[
    'Make',
    'Model',
    'Body_type',
    'drive_wheels',
    'transmission',
    'cylinder_layout',
    'number_of_cylinders',
    'fuel_type',
    'Year_from',
    'Year_to',
    'capacity_cm3',
    'engine_hp',
    'maximum_torque_n_m',
    'acceleration_0_100_km/h_s',
    'max_speed_km_per_h',
    'mixed_fuel_consumption_per_100_km_l',
    'city_fuel_per_100km_l',
    'highway_fuel_per_100km_l',
    'max_trunk_capacity_l',
    'full_weight_kg'
]]
selected_cars = selected_cars.rename(columns={
    'Make': 'make',
    'Model': 'model',
    'Body_type': 'body_type',
    'Year_from': 'year_from',
    'Year_to': 'year_to',
    'capacity_cm3': 'displacement',
    'engine_hp': 'power',
    'maximum_torque_n_m': 'torque',
    'acceleration_0_100_km/h_s': 'acc',
    'max_speed_km_per_h': 'max_speed',
    'mixed_fuel_consumption_per_100_km_l': 'mixed_fc',
    'city_fuel_per_100km_l': 'city_fc',
    'highway_fuel_per_100km_l': 'highway_fc',
    'max_trunk_capacity_l': 'trunk',
    'full_weight_kg': 'weight'
})
selected_cars.head()
# Out:
#      make    pl.ksr.summarizator.model  body_type drive_wheels transmission cylinder_layout  \
# 49  Acura  Integra      Sedan          fwd    Automatic          Inline
# 50  Acura  Integra      Sedan          fwd       Manual          Inline
# 51  Acura  Integra      Sedan          fwd       Manual          Inline
# 54  Acura      MDX  Crossover          awd    Automatic          V-type
# 60  Acura      MDX  Crossover          awd    Automatic          V-type
#
#     number_of_cylinders fuel_type  year_from  year_to  displacement  power  \
# 49                    4  Gasoline       1991     2002          1834    144
# 50                    4  Gasoline       1991     2002          1834    144
# 51                    4  Gasoline       1991     2002          1797    172
# 54                    6  Gasoline       2001     2006          3471    240
# 60                    6  Gasoline       2013     2020          3471    290
#
# ...

# %%
selected_cars.reset_index(drop=True, inplace=True)
selected_cars.to_csv('selected_cars.csv', index=True, index_label='id')
