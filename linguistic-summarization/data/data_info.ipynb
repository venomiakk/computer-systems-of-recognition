# %%
import pandas as pd
df = pd.read_csv('processed_cars.csv')
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None) 
df.head()
# Out:
#    id   Make    Model    Generation  Year_from  Year_to     Series  \
# 0  50  Acura  Integra  1 generation       1991     2002      Sedan
# 1  51  Acura  Integra  1 generation       1991     2002      Sedan
# 2  52  Acura  Integra  1 generation       1991     2002      Sedan
# 3  55  Acura      MDX  1 generation       2001     2006  Crossover
# 4  61  Acura      MDX  3 generation       2013     2020  Crossover
#
#          Trim  Body_type  full_weight_kg  max_trunk_capacity_l drive_wheels  \
# 0      1.8 AT      Sedan            1600                   370          fwd
# 1      1.8 MT      Sedan            1600                   370          fwd
# 2      1.8 MT      Sedan            1650                   311          fwd
# 3  3.5 AT 4WD  Crossover            2580                  2308          awd
# 4  3.5 AT 4WD  Crossover            2575                  1344          awd
#
#   transmission cylinder_layout  number_of_cylinders fuel_type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17077 entries, 0 to 17076
# Data columns (total 30 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   17077 non-null  int64
#  1   Make                                 17077 non-null  object
#  2   Model                                17077 non-null  object
#  3   Generation                           17077 non-null  object
#  4   Year_from                            17077 non-null  int64
#  5   Year_to                              17077 non-null  int64
#  6   Series                               17077 non-null  object
#  7   Trim                                 17077 non-null  object
#  8   Body_type                            17077 non-null  object
#  9   full_weight_kg                       17077 non-null  int64
#  10  max_trunk_capacity_l                 17077 non-null  int64
# ...

# %%
stats = df.describe()
stats.loc['min_max_mean'] = (stats.loc['min'] + stats.loc['max']) / 2
stats.loc[['min_max_mean']]
stats.loc[['min', 'max', 'min_max_mean']]
# Out:
#                    id  Year_from  Year_to  full_weight_kg  \
# min              50.0     1964.0      0.0           950.0
# max           70904.0     2019.0   2020.0          3966.0
# min_max_mean  35477.0     1991.5   1010.0          2458.0
#
#               max_trunk_capacity_l  number_of_cylinders  cylinder_bore_mm  \
# min                           72.0                  2.0              56.0
# max                         5400.0                 12.0             104.0
# min_max_mean                2736.0                  7.0              80.0
#
#               stroke_cycle_mm  capacity_cm3  maximum_torque_n_m  \
# min                      55.0         649.0                44.0
# max                     105.0        6761.0              1020.0
# min_max_mean             80.0        3705.0               532.0
#
#               turnover_of_maximum_torque_rpm  engine_hp  engine_hp_rpm  \
# min                                   1200.0       29.0         1750.0
# ...

# %%
df['Body_type'].unique()
# Out:
# array(['Sedan', 'Crossover', 'Coupe', 'Hatchback', 'Liftback', 'Wagon',
#        'Cabriolet', 'Roadster', 'Minivan', 'Pickup', 'Fastback', 'Targa'],
#       dtype=object)

# %%
df['drive_wheels'].unique()
# Out:
# array(['fwd', 'awd', 'rwd', '4wd'], dtype=object)

# %%
df['transmission'].unique()
# Out:
# array(['Automatic', 'Manual'], dtype=object)

# %%
df['cylinder_layout'].unique()
# Out:
# array(['Inline', 'V-type', 'Opposed', 'W-type', 'Rotary-piston'],
#       dtype=object)

# %%
df['number_of_cylinders'].unique()
# Out:
# array([ 4,  6,  5,  8, 12,  3, 10,  2], dtype=int64)

# %%
df['fuel_type'].unique()
# Out:
# array(['Gasoline', 'Diesel', 'Hybrid', 'Gas'], dtype=object)

# %%
df['number_of_gears'].unique()
# Out:
# array([4, 5, 6, 8, 3, 7, 2, 9], dtype=int64)

# %%
selected_columns = df[[
    'Year_from',
    'capacity_cm3',
    'engine_hp',
    'maximum_torque_n_m',
    'acceleration_0_100_km/h_s',
    'max_speed_km_per_h',
    'mixed_fuel_consumption_per_100_km_l',
    'city_fuel_per_100km_l',
    'highway_fuel_per_100km_l',
    'max_trunk_capacity_l',
    'full_weight_kg'
]]
selected_columns = selected_columns.rename(columns={
    'Year_from': 'year',
    'capacity_cm3': 'displacement',
    'engine_hp': 'power',
    'maximum_torque_n_m': 'torque',
    'acceleration_0_100_km/h_s': 'acc',
    'max_speed_km_per_h': 'max_speed',
    'mixed_fuel_consumption_per_100_km_l': 'mixed_fc',
    'city_fuel_per_100km_l': 'city_fc',
    'highway_fuel_per_100km_l': 'highway_fc',
    'max_trunk_capacity_l': 'trunk',
    'full_weight_kg': 'weight'
})
selected_columns.head()
# Out:
#    year  displacement  power  torque  acc  max_speed  mixed_fc  city_fc  \
# 0  1991          1834    144     173  7.5        205       8.4      9.4
# 1  1991          1834    144     173  7.5        205       8.4      9.4
# 2  1991          1797    172     173  7.2        210       8.6      9.4
# 3  2001          3471    240     332  8.7        190      13.2     13.8
# 4  2013          3471    290     355  7.6        220      10.4     15.1
#
#    highway_fc  trunk  weight
# 0         7.6    370    1600
# 1         7.6    370    1600
# 2         7.6    311    1650
# 3        10.2   2308    2580
# 4         7.7   1344    2575

# %%
selected_columns.to_csv('processed_cars_selected.csv', index=False)
